# %% [markdown]
# #### Test VGG16 transfer learning (model_v4) on random Up/Down-sampled data with same train-test sample-size (N=6000)
#
# ##### Input data
# train-test: N=6000 each --- b_2000 + rand_b_400 || nb_6000
# ** No holdout data
#
# #### refs
# - REF: http://localhost:8888/notebooks/REFS_and_LINKS.ipynb
#
#
# - ref: http://localhost:8888/notebooks/load_Imgs_runtestCNN_v1.ipynb
# - ref: http://localhost:8888/notebooks/load_Imgs_BuildTrainTestarrays_v1.ipynb

# %% [markdown]
# #### General REQs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd

# %%
# !pwd
# path='/Users/hrm/Documents/Dropbox/DSrelated/DG_datachallenge'
path = '/home/ubuntu/pynb/DG_datachallenge'

# %% [markdown]
# #### LOAD Image Arrays

# %%
# LOAD saved vars


# Xtrain=np.load(path+'/building_set/TrainX_v0'+'.npy')
# Ytrain=np.load(path+'/building_set/TrainY_v0'+'.npy')
# # print(Xtrain.shape, Ytrain.shape)


# Xtest=np.load(path+'/building_set/TestX_v0'+'.npy')
# Ytest=np.load(path+'/building_set/TestY_v0'+'.npy')
# # print(Xtest.shape, Ytest.shape)


# LARGE files....
# X_all = np.load(path+'/building_set/X_all'+'.npy')
# Y_all = np.load(path+'/building_set/Y_all'+'.npy')
# print(X_all.shape, Y_all.shape)

X_all = np.load(path+'/building_set/X_ubdnb6000_all'+'.npy')
Y_all = np.load(path+'/building_set/Y_ubdnb6000_all'+'.npy')

# %%
print(X_all.shape, Y_all.shape)
# Out:
# (12000, 256, 256, 3) (12000, 2)

# %%
### Include all images
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X_all, Y_all, 
                                                test_size=0.2, 
                                                random_state=8888, 
                                                stratify=Y_all)

# %%
def convertKerasY21Darray(kerasY):
    return np.argmax(kerasY,axis = 1)

# %%
pd.DataFrame(convertKerasY21Darray(Ytest), columns=['label']).label.value_counts()
# Out:
# 0    1202
# 1    1198
# Name: label, dtype: int64

# %% [markdown]
# ##### DNN try VGG16  ---------------------------------

# %%
# https://keras.io/applications/#inceptionv3
# import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, ZeroPadding2D
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, rmsprop

# from keras.layers import merge
# from keras.layers.core import Lambda
from keras.models import Model

# from keras import backend as K
# import tensorflow as tf

# %%
# https://keras.io/applications/#vgg16
from keras.layers import Input
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

# %%
VGG16().summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544.0
# Trainable params: 138,357,544.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# VGG16 input_tensor = Input(shape=(224, 224, 3)) #default

# %%
# create the base pre-trained model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)

# and a logistic layer -- N classes
predictions = Dense(2, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 15,242,050.0
# Trainable params: 527,362.0
# Non-trainable params: 14,714,688.0
# _________________________________________________________________

# %%
# http://stackoverflow.com/questions/42606207/keras-custom-decision-threshold-for-precision-and-recall
# http://stackoverflow.com/questions/41458859/keras-custom-metric-for-single-class-accuracy

# import keras.backend as K # not working...?

# def mean_pred(y_true, y_pred):
#     return K.mean(y_pred)

# model.compile(optimizer='rmsprop',
#               loss='binary_crossentropy',
#               metrics=['accuracy', mean_pred])


# def precision(y_true, y_pred):
#     """Precision metric.
#     Computes the precision over the whole batch 
#     """
#     # Compute the number of true positives. Rounding in prevention to make sure we have an integer.
#     true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
#     # count the predicted positives
#     predicted_positives = K.sum(y_pred)
#     # Get the precision ratio
#     precision_ratio = true_positives / (predicted_positives + K.epsilon())
#     return precision_ratio



# def recall(y_true, y_pred):
#     """Recall metric.
#     Computes the recall over the whole batch 
#     """
#     # Compute the number of true positives. Rounding in prevention to make sure we have an integer.
#     true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
#     # Compute the number of positive targets.
#     possible_positives = K.sum(K.clip(y_true, 0, 1))
#     recall_ratio = true_positives / (possible_positives + K.epsilon())
#     return recall_ratio

# %%
from keras.optimizers import RMSprop, Adam, SGD
from keras import metrics #https://github.com/fchollet/keras/wiki/Keras-2.0-release-notes
# import keras_metrics

# model = cnn_model()

# compile the model (should be done *after* setting layers to non-trainable)
# model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

lr = 0.001 #0.0001 #0.01
sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(lr=lr),    
              metrics=['accuracy']
              #metrics=['accuracy',precision,recall] # removed from updated keras API || define own?
              )

# train the model on the new data for a few epochs
# model.fit_generator(...)

# %%
from keras.callbacks import History, ModelCheckpoint, EarlyStopping, LearningRateScheduler

# filepath='./model/model_v1c.h5'
# filepath='./model/model_v1d.h5'
# filepath='./model/model_v1e.h5'
# filepath='./model/model_v1f.h5'

# filepath='./model/model_v2.h5' #XY_all
# filepath='./model/model_v2b.h5'

# filepath='./model/model_v3.h5' #XY_ubdnb6000_all

filepath='./model/model_v4.h5' #VGG16_XY_ubdnb6000_all

# filepath = input()

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max') 
history = History()

early_stopping = EarlyStopping(monitor='val_loss', verbose=1, patience=3, mode='auto')

# %%
batch_size = 32
nb_epoch = 20 #10 

def lr_schedule(epoch):
    return lr*(0.1**int(epoch/10))


model.fit(Xtrain, Ytrain, batch_size=batch_size, epochs=nb_epoch,
            validation_split=0.2, shuffle=True, 
          callbacks=[LearningRateScheduler(lr_schedule),
                    early_stopping,checkpoint, history]          
          #callbacks=[early_stopping, checkpoint, history]
         )
# Out:
# Train on 7680 samples, validate on 1920 samples
# Epoch 1/20
# Epoch 00000: val_acc improved from -inf to 0.90104, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 271s - loss: 0.3403 - acc: 0.8490 - val_loss: 0.2483 - val_acc: 0.9010
# Epoch 2/20
# Epoch 00001: val_acc improved from 0.90104 to 0.90573, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.2818 - acc: 0.8823 - val_loss: 0.2295 - val_acc: 0.9057
# Epoch 3/20
# Epoch 00002: val_acc did not improve
# 7680/7680 [==============================] - 266s - loss: 0.2706 - acc: 0.8863 - val_loss: 0.2432 - val_acc: 0.8974
# Epoch 4/20
# Epoch 00003: val_acc did not improve
# 7680/7680 [==============================] - 266s - loss: 0.2589 - acc: 0.8940 - val_loss: 0.2481 - val_acc: 0.9010
# Epoch 5/20
# Epoch 00004: val_acc improved from 0.90573 to 0.91979, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.2471 - acc: 0.8949 - val_loss: 0.2076 - val_acc: 0.9198
# Epoch 6/20
# Epoch 00005: val_acc improved from 0.91979 to 0.92031, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.2456 - acc: 0.9034 - val_loss: 0.2093 - val_acc: 0.9203
# Epoch 7/20
# Epoch 00006: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.2458 - acc: 0.8997 - val_loss: 0.2621 - val_acc: 0.8964
# Epoch 8/20
# Epoch 00007: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.2374 - acc: 0.9003 - val_loss: 0.2366 - val_acc: 0.9078
# Epoch 9/20
# Epoch 00008: val_acc improved from 0.92031 to 0.92865, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.2356 - acc: 0.9027 - val_loss: 0.1926 - val_acc: 0.9286
# Epoch 10/20
# Epoch 00009: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.2276 - acc: 0.9057 - val_loss: 0.2044 - val_acc: 0.9214
# Epoch 11/20
# Epoch 00010: val_acc improved from 0.92865 to 0.93229, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.1954 - acc: 0.9191 - val_loss: 0.1826 - val_acc: 0.9323
# Epoch 12/20
# Epoch 00011: val_acc improved from 0.93229 to 0.93490, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.1864 - acc: 0.9249 - val_loss: 0.1815 - val_acc: 0.9349
# Epoch 13/20
# Epoch 00012: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.1837 - acc: 0.9263 - val_loss: 0.1789 - val_acc: 0.9328
# Epoch 14/20
# Epoch 00013: val_acc improved from 0.93490 to 0.93542, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.1843 - acc: 0.9271 - val_loss: 0.1779 - val_acc: 0.9354
# Epoch 15/20
# Epoch 00014: val_acc improved from 0.93542 to 0.93698, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 267s - loss: 0.1814 - acc: 0.9277 - val_loss: 0.1778 - val_acc: 0.9370
# Epoch 16/20
# Epoch 00015: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.1778 - acc: 0.9313 - val_loss: 0.1769 - val_acc: 0.9370
# Epoch 17/20
# Epoch 00016: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.1767 - acc: 0.9322 - val_loss: 0.1790 - val_acc: 0.9339
# Epoch 18/20
# Epoch 00017: val_acc improved from 0.93698 to 0.93906, saving model to ./model/model_v4.h5
# 7680/7680 [==============================] - 266s - loss: 0.1768 - acc: 0.9307 - val_loss: 0.1760 - val_acc: 0.9391
# Epoch 19/20
# Epoch 00018: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.1738 - acc: 0.9318 - val_loss: 0.1800 - val_acc: 0.9349
# Epoch 20/20
# Epoch 00019: val_acc did not improve
# 7680/7680 [==============================] - 267s - loss: 0.1715 - acc: 0.9332 - val_loss: 0.1791 - val_acc: 0.9344

# %%
#filepath='./model/model_v1c.h5'

# %%
from sklearn.metrics import log_loss

Ypreds = model.predict(Xtest, verbose=1)
print("Validation Log Loss: {}".format(log_loss(Ytest, Ypreds)))
# Out:
# 2400/2400 [==============================] - 66s
# Validation Log Loss: 0.19702922896238412

# %%
# Validation Log Loss: 
# filepath='./model/model_v1c.h5' # >10
# filepath='./model/model_v1d.h5' # 5.18
# filepath='./model/model_v1e.h5' # 2.826
# model_v1e.h5 + sgd instead of rmsprops # 0.69 BUT accuracy ~0.5! Not great.
# filepath='./model/model_v1f.h5' # 9.78

# filepath='./model/model_v2.h5' # 0.28
# filepath='./model/model_v2a.h5' # 0.7
# filepath='./model/model_v2b.h5' # 3.453877639770508

# filepath='./model/model_v3.h5' # 0.1088 *** #XY_ubdnb6000_all

# filepath='./model/model_v4.h5' # 0.197 ** #VGG16_XY_ubdnb6000_all

# %%
def convertKerasY21Darray(kerasY):
    return np.argmax(kerasY,axis = 1)

# %%
Y_preds = convertKerasY21Darray(Ypreds)
Y_test = convertKerasY21Darray(Ytest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy_score(Y_test, Y_preds) 

#filepath='./model/model_v1c.h5' #0.555
#filepath='./model/model_v1d.h5' #0.613
#filepath='./model/model_v1e.h5' #0.576

#filepath='./model/model_v2.h5' #0.910 ??
#filepath='./model/model_v2b.h5' #0.90 ??

#filepath='./model/model_v3.h5' #0.9725 *** #XY_ubdnb6000_all

# filepath='./model/model_v4.h5' #0.92 ** #VGG16_XY_ubdnb6000_all
# Out:
# 0.92041666666666666

# %%
import pandas as pd

# %%
pd.DataFrame(Y_test, columns=['B']).B.value_counts()
# Out:
# 0    1202
# 1    1198
# Name: B, dtype: int64

# %%
print (classification_report(Y_test,Y_preds,target_names = ['no_buildings','buildings']) )
# Out:
#               precision    recall  f1-score   support
#
# no_buildings       0.93      0.91      0.92      1202
#    buildings       0.91      0.93      0.92      1198
#
#  avg / total       0.92      0.92      0.92      2400

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(Y_test,Y_preds)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['no_buildings','buildings'],
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[1097  105]
#  [  86 1112]]

# %%
# list(zip(Y_test,Y_preds))
import pandas as pd

# %%
history.history
# Out:
# {'acc': [0.84895833333333337,
#   0.8822916666666667,
#   0.88632812500000002,
#   0.8940104166666667,
#   0.89492187499999998,
#   0.90338541666666672,
#   0.89973958333333337,
#   0.90026041666666667,
#   0.90273437499999998,
#   0.9057291666666667,
#   0.91914062500000004,
#   0.92486979166666672,
#   0.9263020833333333,
#   0.92708333333333337,
#   0.927734375,
#   0.93125000000000002,
#   0.9321614583333333,
#   0.93072916666666672,
#   0.93177083333333333,
#   0.93320312500000002],
#  'loss': [0.3402662530851861,
#   0.28179514794610439,
#   0.27060920720299086,
#   0.25893066578234236,
#   0.24708235627040268,
#   0.24562263685899477,
#   0.24581705418725808,
#   0.23738620323128998,
#   0.23561535178062817,
#   0.22760361760544282,
#   0.1953926041799908,
#   0.18641161327250302,
#   0.18371785211687286,
#   0.18425688849917302,
#   0.18141865875416746,
#   0.17779294350184499,
#   0.17667314576295515,
#   0.1767648166200767,
#   0.17383764954283834,
#   0.17154272805588941],
#  'val_acc': [0.90104166666666663,
#   0.9057291666666667,
#   0.89739583333333328,
#   0.90104166666666663,
#   0.91979166666666667,
#   0.92031249999999998,
#   0.89635416666666667,
#   0.90781250000000002,
#   0.92864583333333328,
#   0.9213541666666667,
#   0.93229166666666663,
#   0.93489583333333337,
#   0.93281250000000004,
#   0.93541666666666667,
#   0.9369791666666667,
#   0.9369791666666667,
#   0.93385416666666665,
#   0.93906250000000002,
#   0.93489583333333337,
#   0.93437499999999996],
#  'val_loss': [0.24830651804804801,
#   0.22953473652402559,
#   0.24319107023378214,
#   0.24811886356522639,
#   0.20756181006630262,
#   0.20926326364278794,
#   0.26210066825151446,
#   0.23661114952216547,
#   0.19259349362303813,
#   0.20435972896715004,
#   0.18259084659318128,
#   0.18151091771821182,
#   0.17891065981239079,
#   0.17787261474877597,
#   0.17783810334901015,
#   0.17694528438150883,
#   0.17904545937975247,
#   0.17603834755718709,
#   0.17995835896581411,
#   0.17907106038182974]}

# %%
len(history.history['acc'])
# Out:
# 20

# %%
HISTORY = pd.DataFrame(history.history)
HISTORY
# Out:
#          acc      loss   val_acc  val_loss
# 0   0.848958  0.340266  0.901042  0.248307
# 1   0.882292  0.281795  0.905729  0.229535
# 2   0.886328  0.270609  0.897396  0.243191
# 3   0.894010  0.258931  0.901042  0.248119
# 4   0.894922  0.247082  0.919792  0.207562
# 5   0.903385  0.245623  0.920312  0.209263
# 6   0.899740  0.245817  0.896354  0.262101
# 7   0.900260  0.237386  0.907813  0.236611
# 8   0.902734  0.235615  0.928646  0.192593
# 9   0.905729  0.227604  0.921354  0.204360
# 10  0.919141  0.195393  0.932292  0.182591
# 11  0.924870  0.186412  0.934896  0.181511
# 12  0.926302  0.183718  0.932813  0.178911
# 13  0.927083  0.184257  0.935417  0.177873
# 14  0.927734  0.181419  0.936979  0.177838
# 15  0.931250  0.177793  0.936979  0.176945
# 16  0.932161  0.176673  0.933854  0.179045
# 17  0.930729  0.176765  0.939063  0.176038
# 18  0.931771  0.173838  0.934896  0.179958
# 19  0.933203  0.171543  0.934375  0.179071

# %%
# HISTORY.to_csv(path+'/building_set/XY_ubdnb6000_VGG16model_v4History.csv')
HISTORY.to_csv('./model/XY_ubdnb6000_VGG16model_v4History.csv')

# %%
import seaborn as sns

# %%
HISTORY.plot(y=['acc','val_acc'])
HISTORY.plot(y=['loss','val_loss'])

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
n=880 #240 #1000 
print(Y_test[n], Y_preds[n])
array_to_img(Xtest[n])
# Out:
# 1 1
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F6DAB76FD30>

# %%
n=1240 #1000
print(Y_test[n], Y_preds[n])
array_to_img(Xtest[n])
# Out:
# 0 0
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F6DAB712DD8>

# %%
n=999 #240 #1000 
print(Y_test[n], Y_preds[n])
array_to_img(Xtest[n])
# Out:
# 1 0
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F6DAB712F28>
